# %% [markdown]
# ![Galileo](https://github.com/RainieroPV/Ciencia-de-Datos-en-Python/blob/main/images/GalileoLogo.PNG?raw=true  "Galileo")
# > #### Ciencia de Datos en Python, Seccion V
# >>  Rainiero Jose Parrales Vargas
# >>  20032022.
#
# # Reporte sobre GIT
# ___
#
# **GIT** es un sistema de control de versiones, por lo tanto es un software que permite a los desarrolladores mantener un historial completo de cada archivo en un proyecto. Sin embargo, no se necesita ser un desarrollador para usar **GIT**; por ejemplo, puedes usarlo para mantener un historial de todos los archivos de un sitio y cada vez que se cambias uno, se registra una versión del cambio y de ser necesario siempre puedes volver a cualquier versión y restaurarla.
#
# Puede llegarse a confundir que **GIT** se utilice como simplemente una herramienta de copia de seguridad, pero hace mucho más que eso, no solo almacena un historial completo de tus archivos, sino que también almacena la 'versión' de esos archivos a lo largo del historial de un proyecto. Esto te permite usarlo para recuperar información sobre cuándo se editó un archivo, así como la capacidad de ver los cambios exactos realizados en el archivo. Una copia de seguridad simple no incluye estos detalles adicionales.
#
# Nos ayudar a obtener la siguiente informacion:
#
# 1. ¿Quién escribió este módulo?
# 2. ¿Cuándo se editó esta línea en particular de este archivo en particular? ¿Por quién? ¿Por qué fue editado?
# 3. Durante las últimas 1000 revisiones, ¿cuándo / por qué dejó de funcionar una prueba ude regresion?
#
# Creo que es importante tener los comandos mas usados a la mano, ya que nos servira en todo el transcurso del postgrado , por lo tanto inclui el listado que miro mas util. __*Claro que **GIT** tiene muchisimos mas*__
#
# ## Comandos mas usados
# ___
# ### Comandos Basicos
# | Comando | Description |
# | ------ | ----------- |
# | git help \<command>  | ayuda del comando GIT a usar |
# | git init | crea un nuevo repositorio  |
# | git status    | Muestra el estatus actual |
# | git add \<filename>    | agrega archivos al área de preparación |
# | git commit    | crea un nuevo commit |
# | git log    | muestra la historia en lista |
# | git log --all --graph --decorate    | emuestra la historia simulando forma de arbol |
# | git diff \<filename>    | mostrar los cambios que realizó en relación con el que esta en staging |
# | git diff \<revision> \<filename>    | muestra diferencias en un archivo entre instantáneas|
# | git checkout \<revision>    | Actualiza el HEAD y la rama actual|
#
#
# ### Branching y Merging
# | Comando | Description |
# | ------ | ----------- |
# |git branch| muestra los branches |
# |git branch <name>| Crea un nuevo branch|
# |git checkout -b <name>| Crea un nuevo branch y lo cambia al actual|
# |git merge <revision>| Hace un Merge con el que cambiamos |
# |git mergetool| Usa la herramienta default para tratar de hacer un Merge |
#
# ### Remoto
# | Comando | Description |
# | ------ | ----------- |
# |git remote| lista los remotos |
# |git remote add <name> \<url>| agrega un remoto |
# |git push \<remote> \<local branch> : \<remote branch> | enviar objetos a remoto y actualizar la referencia remota |
# |git branch --set-upstream-to=\<remote>/\<remote branch>| Establecer correspondencia entre la version local y remota |
# |git fetch| recuperar objetos / referencias del remoto |
# |git pull| lo mismo que git fetch; git merge |
# |git clone| descargar repositorio desde un remoto |
#
# ### Deshacer
# | Comando | Description |
# | ------ | ----------- |
# |git commit --amend| Edita el comentario que se hara en el commit |
# |git reset HEAD \<file>| desmontar un archivo |
# |git checkout -- \<file>| descartar los cambios |
#
#
# ## Para nuestro laboratorio
# ___
#
# + Luego de crear mi proyecto in GTHUB, clono mi proyecto en mi computadora local
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo
# $ git clone https://github.com/RainieroPV/Ciencia-de-Datos-en-Python.git ./
# Cloning into '.'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.
#
# No commits yet
# ```
# + Para este punto e creado mi notebook y carpeta con las imagenes que usare
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git status
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#         .ipynb_checkpoints/
#         Hoja_de_Trabajo_1.ipynb
#         images/
#
# nothing added to commit but untracked files present (use "git add" to track)
# ```
#
# + Agrego la carpeta imagenes
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git add images
# ```
#
# + Hago commit de la imagen
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git commit
# [main 7ca6c40] + add the images that I will use in my Notebook
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 images/GalileoLogo.PNG
# ```
#
# + Lo mismo hago para my notebook para agregarlo a mi repositorio y actualizar el remoto
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git add Hoja_de_Trabajo_1.ipynb
# warning: LF will be replaced by CRLF in Hoja_de_Trabajo_1.ipynb.
# The file will have its original line endings in your working directory
#
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git commit
# [main ea61f1d] + Adding the notebook -Hoja de Trabajo 1
#  1 file changed, 394 insertions(+)
#  create mode 100644 Hoja_de_Trabajo_1.ipynb
#
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git log --all --graph --decorate
# * commit ea61f1db79f101d09c736e02186268da3c1174f8 (HEAD -> main)
# | Author: Rainiero Parrales <rparrales_vargas@hotmail.com>
# | Date:   Sun Feb 14 16:12:15 2021 -0600
# |
# |     + Adding the notebook -Hoja de Trabajo 1
# |
# * commit 7ca6c405726ad83e0be22d6b4ec2dad0cf7fc1c7
# | Author: Rainiero Parrales <rparrales_vargas@hotmail.com>
# | Date:   Sun Feb 14 15:58:34 2021 -0600
# |
# |     + add the images that I will use in my Notebook
# |
# * commit 2571af3a2e7a6feada0194e160b403ec5f4b8b0c (origin/main, origin/HEAD)
#   Author: RainieroPV <78708695+RainieroPV@users.noreply.github.com>
#   Date:   Mon Feb 8 09:45:24 2021 -0600
#
#       Initial commit
# ```
# + Luego hago push para actualizar el nodo remoto
#
# ```bash
# rparr@DESKTOP-D7U2HDV MINGW64 ~/Documents/TOMIA/Maestria/Ciencia de Datos en Python/Hojas_de_trabajo (main)
# $ git push -u
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 18.11 KiB | 4.53 MiB/s, done.
# Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/RainieroPV/Ciencia-de-Datos-en-Python.git
#    2571af3..ea61f1d  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# ```
# ---
# ### Conclusiones
#
# 1. Git hace el trabajo en equipo más ágil y sencillo, ayuda a la detección de fallos, a disminuir errores humanos, al seguimiento por etapas del proyecto, al mantenimiento de diferentes entornos, etc.
# 2. Podemos ver la historia de desarrollo , regresar a nodos pasados por cambios o bugs que no teniamos antes.
# 3. Podemos tener el sitio remoto en una maquina dentro de la misma red por lo que no es mandatorio un repositorio WEB para poderlo usar , sin embargo para esta tarea usamos GITHUB.
# 4. Podemos decir que alojar proyectos como repositorios en Git es una decisión profesional inteligente, porque te beneficiarás de los conocimientos de otros programadores.
# 5. dispondrás de un robusto sistema de gestión de proyectos que hará que el trabajo en equipo sea mucho más rápido
#
# ---
#
# ### Ceomentarios
#
# 1. Creo que en un inicio cuesta entender la metodologia y el concepto de versiones en GIT, sin embargo luego de jugat con laherramienta y hacer los pasos que se vio en el video , se entiende como se trabajan las versiones y como un equipo puede ir colaborando.
# 2. Realmente el control de versiones y poder regresar a un commit pasado es algo muy util en ambientes de desarrollo ya que se puede regresar en caso de versiones nuevas con errores.
# 3. Tambien me gusto la logica de verlo como control de versiones de cualquier cosa , lo cual amplie la utilidad de esta herramienta y no se encasilla en solo programacion.
#
# ---
# __Informacion basada en:__
#
# - __[GIT MIT](https://missing.csail.mit.edu/2020/version-control/)__ - Leccion sobre GIT / video de referencia
#
# ~~FIN DEL REPORTE~~
